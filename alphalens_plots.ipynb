# %%
import alphalens
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# %%
factor_data = pd.read_csv('factor_data.csv')

# %%
factor_data['date'] = pd.to_datetime(factor_data['date'])

# %%
factor_data.set_index(['date', 'asset'], inplace=True)

# %%
factor_data.head()
# Out:
#                                                1D   5D  10D    factor  \
# date                      asset
# 2016-02-01 00:00:00+00:00 0876218D LN Equity  0.0  0.0  0.0  0.000778
#                           1043154Q LN Equity  0.0  0.0  0.0  0.000778
#                           1294047D SS Equity  0.0  0.0  0.0  0.000778
#                           1340426D GF Equity  0.0  0.0  0.0  0.000778
#                           1340426D GY Equity  0.0  0.0  0.0  0.000778
#
#                                               factor_quantile
# date                      asset
# 2016-02-01 00:00:00+00:00 0876218D LN Equity              3.0
#                           1043154Q LN Equity              4.0
#                           1294047D SS Equity              3.0
#                           1340426D GF Equity              4.0
#                           1340426D GY Equity              3.0

# %%
alphalens.tears.create_full_tear_sheet(factor_data)
# Out:
# Quantiles Statistics
#                       min       max      mean       std   count    count %
# factor_quantile
# 1.0             -0.003195  0.000807 -0.000632  0.000529  201980  20.047663
# 2.0             -0.001325  0.000942 -0.000133  0.000576  201175  19.967762
# 3.0             -0.000974  0.001258  0.000214  0.000609  201196  19.969846
# 4.0             -0.000840  0.001805  0.000604  0.000583  201256  19.975801
# 5.0             -0.000677  0.004853  0.001193  0.000554  201892  20.038928
# Returns Analysis
#                                                    1D     5D    10D
# Ann. alpha                                      0.243  0.074  0.032
# beta                                            0.067  0.113  0.099
# Mean Period Wise Return Top Quantile (bps)     11.859  4.884  2.804
# Mean Period Wise Return Bottom Quantile (bps)  -8.920 -2.796 -0.981
# Mean Period Wise Spread (bps)                  20.780  7.655  3.758
# Information Analysis
#                      1D     5D    10D
# IC Mean           0.043  0.035  0.024
# IC Std.           0.120  0.119  0.116
# Risk-Adjusted IC  0.354  0.298  0.205
# t-stat(IC)        9.801  8.235  5.682
# p-value(IC)       0.000  0.000  0.000
# IC Skew           0.136  0.269  0.299
# IC Kurtosis       2.355  2.014  1.586
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-91c0f91dd87f> in <module>
# ----> 1 alphalens.tears.create_full_tear_sheet(factor_data)
#
# ~\Anaconda3\lib\site-packages\alphalens\plotting.py in call_w_context(*args, **kwargs)
#      43             with plotting_context(), axes_style(), color_palette:
#      44                 sns.despine(left=True)
# ---> 45                 return func(*args, **kwargs)
#      46         else:
#      47             return func(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\alphalens\tears.py in create_full_tear_sheet(factor_data, long_short, group_neutral, by_group)
#     488                                   by_group,
#     489                                   set_context=False)
# --> 490     create_turnover_tear_sheet(factor_data, set_context=False)
#     491
#     492
#
# ~\Anaconda3\lib\site-packages\alphalens\plotting.py in call_w_context(*args, **kwargs)
#      45                 return func(*args, **kwargs)
#      46         else:
# ---> 47             return func(*args, **kwargs)
#      48     return call_w_context
#      49
#
# ~\Anaconda3\lib\site-packages\alphalens\tears.py in create_turnover_tear_sheet(factor_data, turnover_periods)
#     415                        for q in range(1, int(quantile_factor.max()) + 1)],
#     416                       axis=1)
# --> 417             for p in turnover_periods}
#     418
#     419     autocorrelation = pd.concat(
#
# ~\Anaconda3\lib\site-packages\alphalens\tears.py in <dictcomp>(.0)
#     415                        for q in range(1, int(quantile_factor.max()) + 1)],
#     416                       axis=1)
# --> 417             for p in turnover_periods}
#     418
#     419     autocorrelation = pd.concat(
#
# ~\Anaconda3\lib\site-packages\alphalens\tears.py in <listcomp>(.0)
#     413     quantile_turnover = \
#     414         {p: pd.concat([perf.quantile_turnover(quantile_factor, q, p)
# --> 415                        for q in range(1, int(quantile_factor.max()) + 1)],
#     416                       axis=1)
#     417             for p in turnover_periods}
#
# ~\Anaconda3\lib\site-packages\alphalens\performance.py in quantile_turnover(quantile_factor, quantile, period)
#     738         shifted_idx = utils.add_custom_calendar_timedelta(
#     739                 quant_name_sets.index, -pd.Timedelta(period),
# --> 740                 quantile_factor.index.levels[0].freq)
#     741         name_shifted = quant_name_sets.reindex(shifted_idx)
#     742         name_shifted.index = quant_name_sets.index
#
# ~\Anaconda3\lib\site-packages\alphalens\utils.py in add_custom_calendar_timedelta(input, timedelta, freq)
#     913     """
#     914     if not isinstance(freq, (Day, BusinessDay, CustomBusinessDay)):
# --> 915         raise ValueError("freq must be Day, BDay or CustomBusinessDay")
#     916     days = timedelta.components.days
#     917     offset = timedelta - pd.Timedelta(days=days)
#
# ValueError: freq must be Day, BDay or CustomBusinessDay
